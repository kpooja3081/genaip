# %%
print("hi")
# Out:
# hi

# %%
words = [[word] for sentence in tokens for word in sentence]
print(words)
encoder = OneHotEncoder(sparse_output=False)
encoder =encoder.fit(words)
print(encoder)
# Out:
# [['my'], ['name'], ['is'], ['pooja']]
# OneHotEncoder(sparse_output=False)

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy
document = ["my name is pooja"]
tokens = [sentence.lower().split() for sentence in document]
print(tokens)
# Out:
# [['my', 'name', 'is', 'pooja']]

# %%
print("hi")
# Out:
# hi

# %%
print("word to vec")
# Out:
# word to vec

# %%
from gensim.models import Word2Vec,KeyedVectors
import gensim.downloader as api

# %%
model.similarity("women","men")
# Out:
# 0.7674937

# %%
model = api.load("word2vec-google-news-300")

# %%
model.doesnt_match("breakfast cereal dinner lunch".split())
# Out:
# 'cereal'

# %%
vec = model["king"]-model['queen'] +model ['women']

# %%
model.most_similar()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 model.most_similar()
#
# File c:\Users\mecha\OneDrive\Desktop\Pooja_personal\krish\venv\Lib\site-packages\gensim\models\keyedvectors.py:843, in KeyedVectors.most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     840         weight[idx] = item[1]
#     842 # compute the weighted average of all keys
# --> 843 mean = self.get_mean_vector(keys, weight, pre_normalize=True, post_normalize=True, ignore_missing=False)
#     844 all_keys = [
#     845     self.get_index(key) for key in keys if isinstance(key, _KEY_TYPES) and self.has_index_for(key)
#     846 ]
#     848 if indexer is not None and isinstance(topn, int):
#
# ...

# %%
sentence = "my name is pooja"
words = sentence.lower().split()

# %%
word_vectors =[]

# %%
for word in words:
    print(word)
    word_vectors.append(model[word])
# Out:
# my
# name
# is
# pooja

# %%
import numpy as np
sentence_vector = np.mean(word_vectors, axis=0)
sentence_vector.shape
# Out:
# (300,)

# %%
word_vectors
# Out:
# [array([ 1.44531250e-01,  4.71191406e-02,  1.00585938e-01,  3.28125000e-01,
#         -2.02636719e-02, -1.72119141e-02,  3.78417969e-02, -1.34765625e-01,
#         -1.25976562e-01,  9.71679688e-02, -9.17968750e-02, -1.02539062e-01,
#          1.99890137e-03, -3.58886719e-02, -4.02343750e-01,  5.29785156e-02,
#          3.12500000e-01,  1.15234375e-01,  1.49414062e-01, -1.45507812e-01,
#         -2.09960938e-02,  1.90429688e-01,  1.31835938e-01,  4.51660156e-02,
#         -1.43554688e-01,  5.29785156e-02, -1.01562500e-01,  1.70898438e-02,
#          1.11328125e-01, -8.39843750e-02,  2.40234375e-01,  2.67333984e-02,
#          2.25830078e-02,  2.19726562e-01,  7.59124756e-04, -1.08886719e-01,
#          1.39648438e-01,  7.71484375e-02,  1.11083984e-02, -2.68554688e-02,
#         -3.15856934e-03,  1.24511719e-02,  3.02734375e-01,  1.13525391e-02,
#          2.85156250e-01,  1.98242188e-01, -1.22680664e-02,  2.28271484e-02,
# ...
