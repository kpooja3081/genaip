# %%
from gensim.models import Word2Vec
import numpy as np
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mecha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
import os
for file in os.listdir('./data'):
    print(file)
# Out:
# story.txt
# story2.txt

# %%
folder_path = r"D:\Users\mecha\OneDrive\Desktop\Pooja_personal\krish\data"
story =[]
for filename in os.listdir(folder_path):
    with open(os.path.join(folder_path, filename)):
# Out:
#   Cell In[125], line 6
#
#     ^
# SyntaxError: incomplete input

# %%
folder_path = r"C:\Users\mecha\OneDrive\Desktop\Pooja_personal\krish\data"
story = []

for filename in os.listdir(folder_path):
    with open(os.path.join(folder_path, filename), 'r') as f:
        content = f.read()
        story.append(content)
        print(f"Read: {filename}")

print(f"\nTotal files read: {len(story)}")

# %%
f =open

# %%
custom_model = gensim.models.Word2Vec(
    window= 10,
    #min_count = 5,
    vector_size = 100
)

# %%
from gensim.models import Word2Vec
Word2Vec(...,sg = 0)
Word2Vec(...,sg = 1)

# %%
custom_model.build_vocab(story)

# %%
custom_model.train(story,total_examples=custom_model.corpus_count, epochs=10)

# %%
custom_model.corpus_count

# %%
custom_model.wv["arjun".lower()]

# %%
len(custom_model.wv["arjun".lower()])

# %%
len(story)

# %% [markdown]
# custom_model

# %%
custom_model.build_vocab(story)

# %%
custom_model.raw_vocab

# %%
model.wv["arjun"]  # Returns [0.23, -0.45, 0.12, ...]  (100 numbers)

# %%
import pandas as pd
import numpy as np
import os
import gensim
import nltk

# %%
nltk.download('punkt')

# %%
for file in os.listdir('./data'):
    print(file)

# %%
f

# %%
corpus = content

# %%
corpus

# %%
sent_tokenize(corpus)

# %%
raw_sent = sent_tokenize(corpus)

# %%
for i in raw_sent:
    print(simple_preprocess(i))

# %%
folder_path = r"D:\Users\mecha\OneDrive\Desktop\Pooja_personal\krish\data"

# %%
story = []
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    with open(file_path, encoding='unicode_escape') as f:
        corpus = f.read()
        raw_sent = sent_tokenize(corpus)
        for sent in raw_sent:
            story.append(simple_preprocess(sent))

# %%
from gensim.models import Word2Vec
import numpy as np
import nltk

# %%
nltk.download('punkt')

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
import os
for file in os.listdir('./data'):
    print(file)

# %%
folder_path = r"D:\Users\mecha\OneDrive\Desktop\Pooja_personal\krish\data"
story =[]
for filename in os.listdir(folder_path):
    with open(os.path.join(folder_path, filename)):

# %%
folder_path = r"C:\Users\mecha\OneDrive\Desktop\Pooja_personal\krish\data"
story = []

for filename in os.listdir(folder_path):
    with open(os.path.join(folder_path, filename), 'r') as f:
        content = f.read()
        story.append(content)
        print(f"Read: {filename}")

print(f"\nTotal files read: {len(story)}")

# %%
f =open

# %%
custom_model = gensim.models.Word2Vec(
    window= 10,
    #min_count = 5,
    vector_size = 100
)

# %%
from gensim.models import Word2Vec
Word2Vec(...,sg = 0)
Word2Vec(...,sg = 1)

# %%
print("hi")
# Out:
# hi

# %%
len(story)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 len(story)
#
# NameError: name 'story' is not defined

# %%
custom_model.build_vocab(story)

# %%
custom_model.train(story,total_examples=custom_model.corpus_count, epochs=10)

# %%
custom_model.corpus_count

# %%
custom_model.wv["arjun".lower()]

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
custom_model.wv.most_similar("arjun")
